# %%
#############################################################################
# zlib License
#
# (C) 2023 Zach Flowers, Murtaza Safdari <musafdar@cern.ch>
#
# This software is provided 'as-is', without any express or implied
# warranty.  In no event will the authors be held liable for any damages
# arising from the use of this software.
#
# Permission is granted to anyone to use this software for any purpose,
# including commercial applications, and to alter it and redistribute it
# freely, subject to the following restrictions:
#
# 1. The origin of this software must not be misrepresented; you must not
#    claim that you wrote the original software. If you use this software
#    in a product, an acknowledgment in the product documentation would be
#    appreciated but is not required.
# 2. Altered source versions must be plainly marked as such, and must not be
#    misrepresented as being the original software.
# 3. This notice may not be removed or altered from any source distribution.
#############################################################################

# %% [markdown]
# # Imports

# %%
#%%
# %matplotlib inline
import matplotlib.pyplot as plt
import logging
import i2c_gui
import i2c_gui.chips
from i2c_gui.usb_iss_helper import USB_ISS_Helper
from i2c_gui.fpga_eth_helper import FPGA_ETH_Helper
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
# import time
from tqdm import tqdm
# from i2c_gui.chips.etroc2_chip import register_decoding
import os, sys
import multiprocessing
os.chdir(f'/home/{os.getlogin()}/ETROC2/ETROC_DAQ')
import run_script
import parser_arguments
import importlib
importlib.reload(run_script)
import datetime
import pandas
from pathlib import Path
import subprocess
import sqlite3
from notebooks.notebook_helpers import *
from fnmatch import fnmatch
import scipy.stats as stats
from math import ceil

# %% [markdown]
# # Set defaults

# %%
hostname = "192.168.2.3"
polarity = "0x8023" # "0x0023" or "0x0027"

# %% [markdown]
# # Run One Time DAQ to Set FPGA Firmware

# %%
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 30 -o clear_fifo -v -w -s 0x0000 -p {polarity} -d 0x1800 -a 0x0001 --clear_fifo --start_DAQ_pulse --stop_DAQ_pulse --check_valid_data_start --skip_binary".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj repeatedQInj L1A L1ARange BCR')
# IPC_queue.put('memoFC Start Triggerbit QInj L1A BCR') 

while not IPC_queue.empty():
    pass
time.sleep(25)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser
# Out:
# start main process
# Setting firmware...
# writing: 0b1 into register 15
# Written into Reg 7:  0000000000000000
# Time (s) for counting stats in FPGA:  000000 0
# Enable Channel Trigger Bit 1 clock delay:  0000
#
#
# Written into Reg 8:  0001100000000000
# Enhance data LED (LED Page 011):  1
# Enable L1A upon Rx trigger bit :  0
# 10 bit delay (trigger bit->L1A):  0000000000 0
#
#
# Written into Reg 11:  0000110111101011
# Written into Reg 12:  0000000001110000
#
#
# Written into Reg 13:  0000000000000000
# Data Rate              :  00
# LED pages              :  000
# Testmode               :  0
# Timestamp (active low) :  0
# DEV Status Page        :  00
#
#
# Written into Reg 14:  0000000000100011
# Fixed time filler (every 25ms) :  0
# Bit Latency                    :  0000
# Falling Edge                   :  0
# Manual mode (set polarity man) :  0
# Sample Event (1/1000 data eth) :  0
# Simple_handshake (Async AIDA)  :  0
# Add Ethernet Filler            :  1
# Enable Debug mode              :  0
# Enable Dumping mode            :  0
# Polarity                       :  0
# Disable GTX                    :  1
# Enable AutoSync                :  1
#
#
# Written into Reg 15  :  0000000000000001
# Channel Enable       :  0001
# WS Trig Stop Delay   :  000
# Enable WS Trigger    :  0
# Triple Trigger       :  0
# Trigger OR Logic     :  0
# Enable Global Trigger:  0
# Global Trigger Delay :  00000
#
#
# Clearing FIFO...
# Waited for 2 secs
# Clearing Event Counter...
# Starting DAQ on FPGA...
# Status of DAQ Toggle before Start Pulse:  0011110001011101
# Status of DAQ Toggle after Start Pulse:  0011110001011111
# Directory ../ETROC-Data/2024-03-25_Array_Test_Results already exists!
# User defined directory ../ETROC-Data/2024-03-25_Array_Test_Results/clear_fifo already created!
# Receive_data is reading data and pushing to the queue...Write_data is reading queue and pushing binary onwards...
#
# Message: memoFC Start Triggerbit QInj repeatedQInj L1A L1ARange BCRTranslate_data is reading queue and translating file 0...
#
# Done with memoFC configuration
# (Unique) Status on Data Stream: 00001111111100000001
# (Unique) Status on Data Stream: 00001100101010001010
# (Unique) Status on Data Stream: 00011010110010111100
# Translate_data is reading queue and translating file 1...
# Translate_data is reading queue and translating file 2...
# Translate_data is reading queue and translating file 3...
# Translate_data is reading queue and translating file 4...
# (Unique) Status on Data Stream: 01001100010010001111
# Translate_data is reading queue and translating file 5...
# (Unique) Status on Data Stream: 00011011010011000110
# Translate_data is reading queue and translating file 6...
# (Unique) Status on Data Stream: 00010000100011000101
# (Unique) Status on Data Stream: 10011110010010111100
# (Unique) Status on Data Stream: 10011000110011000101
# (Unique) Status on Data Stream: 10011000110010111101
# Translate_data is reading queue and translating file 7...
# (Unique) Status on Data Stream: 00011001000010111011
# Translate_data is reading queue and translating file 8...
# Translate_data is reading queue and translating file 9...
# Translate_data is reading queue and translating file 10...
# Translate_data is reading queue and translating file 11...
# Translate_data is reading queue and translating file 12...
# (Unique) Status on Data Stream: 10101001010010111111
# Translate_data is reading queue and translating file 13...
# Translate_data is reading queue and translating file 14...
# (Unique) Status on Data Stream: 00011010010010111101
# (Unique) Status on Data Stream: 00011011110011000110
# (Unique) Status on Data Stream: 01001100001010011110
# Translate_data is reading queue and translating file 15...
# (Unique) Status on Data Stream: 00010110100011000010
# Translate_data is reading queue and translating file 16...
# Translate_data is reading queue and translating file 17...
# (Unique) Status on Data Stream: 00010110110011000010
# Translate_data is reading queue and translating file 18...
# Translate_data is reading queue and translating file 19...
# (Unique) Status on Data Stream: 00100010010010111101
# (Unique) Status on Data Stream: 00100000110011000101
# (Unique) Status on Data Stream: 00011101000010111100Translate_data is reading queue and translating file 20...
#
# Translate_data is reading queue and translating file 21...
# (Unique) Status on Data Stream: 00011001100010111100
# Translate_data is reading queue and translating file 22...
# (Unique) Status on Data Stream: 00010111100010111101
# (Unique) Status on Data Stream: 11001100011110001010
# (Unique) Status on Data Stream: 10001100001110011100
# Translate_data is reading queue and translating file 23...
# Translate_data is reading queue and translating file 24...
# Translate_data is reading queue and translating file 25...
# (Unique) Status on Data Stream: 10011101010010111100
# (Unique) Status on Data Stream: 00001100000110011001
# (Unique) Status on Data Stream: 10001100100110000110
# (Unique) Status on Data Stream: 00001110010011001010
# (Unique) Status on Data Stream: 10001011101110010001
# (Unique) Status on Data Stream: 00011100110010111011
# Translate_data is reading queue and translating file 26...
# (Unique) Status on Data Stream: 00010110100010111010
# Translate_data is reading queue and translating file 27...
# Translate_data is reading queue and translating file 28...
# (Unique) Status on Data Stream: 00001110010011000010Translate_data is reading queue and translating file 29...
#
# (Unique) Status on Data Stream: 01001000000010000011Translate_data is reading queue and translating file 30...
#
# Translate_data is reading queue and translating file 31...
# Translate_data is reading queue and translating file 32...
# Translate_data is reading queue and translating file 33...
# (Unique) Status on Data Stream: 00001110010011000001
# Translate_data is reading queue and translating file 34...
# Translate_data is reading queue and translating file 35...
# Translate_data is reading queue and translating file 36...
# (Unique) Status on Data Stream: 00011001100010111101
# (Unique) Status on Data Stream: 00001001100011000010
# Message: stop DAQ
# Message: memoFC Triggerbit
# Done with memoFC configuration
# Message: allow threads to exit
# Translate_data is reading queue and translating file 37...
# Read Thread gracefully sending STOP signal to other threads
# Sending stop signal to Write Thread
# Receive_data finished!
# Write Thread received STOP signal AND ran out of data to write
# Write Thread gracefully sending STOP signal to translate thread
# Write_data finished!
# Translate Thread received STOP signal AND ran out of data to translate
# Translate Thread gracefully ending
# Translate_data finished!
# Stopping DAQ on FPGA...
# Status of DAQ Toggle before Stop Pulse:  0011110001011111
# Status of DAQ Toggle after Stop Pulse:  0011110001011101

# %%
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o clear_fifo -v -w -s 0x0000 -p {polarity} -d 0x1800 -a 0x0001 --start_DAQ_pulse --stop_DAQ_pulse ".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj L1A BCR')
while not IPC_queue.empty():
    pass
time.sleep(10)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser
# Out:
# start main process
# Setting firmware...
# writing: 0b1 into register 15
# Written into Reg 7:  0000000000000000
# Time (s) for counting stats in FPGA:  000000 0
# Enable Channel Trigger Bit 1 clock delay:  0000
#
#
# Written into Reg 8:  0001100000000000
# Enhance data LED (LED Page 011):  1
# Enable L1A upon Rx trigger bit :  0
# 10 bit delay (trigger bit->L1A):  0000000000 0
#
#
# Written into Reg 11:  0000110111101011
# Written into Reg 12:  0000000001110000
#
#
# Written into Reg 13:  0000000000000000
# Data Rate              :  00
# LED pages              :  000
# Testmode               :  0
# Timestamp (active low) :  0
# DEV Status Page        :  00
#
#
# Written into Reg 14:  1100000000100011
# Fixed time filler (every 25ms) :  1
# Bit Latency                    :  0000
# Falling Edge                   :  0
# Manual mode (set polarity man) :  0
# Sample Event (1/1000 data eth) :  0
# Simple_handshake (Async AIDA)  :  0
# Add Ethernet Filler            :  1
# Enable Debug mode              :  0
# Enable Dumping mode            :  0
# Polarity                       :  0
# Disable GTX                    :  1
# Enable AutoSync                :  1
#
#
# Written into Reg 15  :  0000000000000001
# Channel Enable       :  0001
# WS Trig Stop Delay   :  000
# Enable WS Trigger    :  0
# Triple Trigger       :  0
# Trigger OR Logic     :  0
# Enable Global Trigger:  0
# Global Trigger Delay :  00000
#
#
# Starting DAQ on FPGA...
# Status of DAQ Toggle before Start Pulse:  0011110001011101
# Status of DAQ Toggle after Start Pulse:  0011110001011111
# Directory ../ETROC-Data/2024-03-22_Array_Test_Results already exists!
# User defined directory ../ETROC-Data/2024-03-22_Array_Test_Results/clear_fifo already created!
# Receive_data is reading data and pushing to the queue...
# Write_data is reading queue and writing file 0...Message: memoFC Start Triggerbit QInj L1A BCRTranslate_data is reading queue and translating file 0...
#
#
# Done with memoFC configuration
# (Unique) Status on Data Stream: 00001111110100000010
# (Unique) Status on Data Stream: 00001111111100000010
# (Unique) Status on Data Stream: 00001111110100000010
# (Unique) Status on Data Stream: 00001111111100000010
# (Unique) Status on Data Stream: 00001111110100000010
# (Unique) Status on Data Stream: 00001111110100000011
# Write_data is reading queue and writing file 1...
# Translate_data is reading queue and translating file 1...
# Write_data is reading queue and writing file 2...
# Translate_data is reading queue and translating file 2...
# Write_data is reading queue and writing file 3...
# Translate_data is reading queue and translating file 3...
# Write_data is reading queue and writing file 4...
# Translate_data is reading queue and translating file 4...
# Write_data is reading queue and writing file 5...
# Translate_data is reading queue and translating file 5...
# Write_data is reading queue and writing file 6...
# Translate_data is reading queue and translating file 6...
# Write_data is reading queue and writing file 7...
# Translate_data is reading queue and translating file 7...
# Write_data is reading queue and writing file 8...
# Translate_data is reading queue and translating file 8...
# Write_data is reading queue and writing file 9...
# Translate_data is reading queue and translating file 9...
# Write_data is reading queue and writing file 10...
# Translate_data is reading queue and translating file 10...
# Write_data is reading queue and writing file 11...
# Translate_data is reading queue and translating file 11...
# Write_data is reading queue and writing file 12...
# Translate_data is reading queue and translating file 12...
# Write_data is reading queue and writing file 13...
# Translate_data is reading queue and translating file 13...
# Write_data is reading queue and writing file 14...
# Translate_data is reading queue and translating file 14...
# Write_data is reading queue and writing file 15...
# Translate_data is reading queue and translating file 15...
# Write_data is reading queue and writing file 16...
# Translate_data is reading queue and translating file 16...
# Write_data is reading queue and writing file 17...
# Translate_data is reading queue and translating file 17...
# Write_data is reading queue and writing file 18...
# Translate_data is reading queue and translating file 18...
# Write_data is reading queue and writing file 19...
# Translate_data is reading queue and translating file 19...
# Write_data is reading queue and writing file 20...
# Translate_data is reading queue and translating file 20...
# Write_data is reading queue and writing file 21...
# Translate_data is reading queue and translating file 21...
# Write_data is reading queue and writing file 22...
# Translate_data is reading queue and translating file 22...
# Write_data is reading queue and writing file 23...
# Translate_data is reading queue and translating file 23...
# Write_data is reading queue and writing file 24...
# Translate_data is reading queue and translating file 24...
# Write_data is reading queue and writing file 25...
# Translate_data is reading queue and translating file 25...
# Write_data is reading queue and writing file 26...
# Translate_data is reading queue and translating file 26...
# Write_data is reading queue and writing file 27...
# Translate_data is reading queue and translating file 27...
# Write_data is reading queue and writing file 28...
# Translate_data is reading queue and translating file 28...
# Write_data is reading queue and writing file 29...
# Translate_data is reading queue and translating file 29...
# Write_data is reading queue and writing file 30...
# Translate_data is reading queue and translating file 30...
# Write_data is reading queue and writing file 31...
# Translate_data is reading queue and translating file 31...
# Write_data is reading queue and writing file 32...
# Translate_data is reading queue and translating file 32...
# Write_data is reading queue and writing file 33...
# Translate_data is reading queue and translating file 33...
# Write_data is reading queue and writing file 34...
# Translate_data is reading queue and translating file 34...
# Write_data is reading queue and writing file 35...
# Translate_data is reading queue and translating file 35...
# Write_data is reading queue and writing file 36...Message: stop DAQ
#
# Message: memoFC TriggerbitTranslate_data is reading queue and translating file 36...
#
# Done with memoFC configuration
# Message: allow threads to exit
# Read Thread gracefully sending STOP signal to other threads
# Sending stop signal to Write Thread
# Receive_data finished!
# Write Thread received STOP signal AND ran out of data to write
# Write Thread gracefully sending STOP signal to translate thread
# Write_data finished!
# Translate Thread received STOP signal AND ran out of data to translate
# Translate Thread gracefully ending
# Translate_data finished!
# Stopping DAQ on FPGA...
# Status of DAQ Toggle before Stop Pulse:  0011110001011111
# Status of DAQ Toggle after Stop Pulse:  0011110001011101

# %%
trigger_bit_delay = int('000111'+format(484, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 30 -o CanBeRemoved_Board0_selfTrigger -v -w -s 0x0000 -p {polarity} -d {trigger_bit_delay} -a 0x000f --start_DAQ_pulse --stop_DAQ_pulse --check_valid_data_start --suppress_fillers".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board0_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
# IPC_queue.put('memoFC Start Triggerbit BCR')
while not IPC_queue.empty():
    pass
time.sleep(25)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %% [markdown]
# #### check LEDs

# %%
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o LED_check -v -w -s 0x0000 -p {polarity} -d 0x1800 -a 0x000f --nodaq".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()
time.sleep(10)
process.join()

del IPC_queue, process, parser

parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o LED_check -v -w -s 0x0004 -p {polarity} -d 0x1800 -a 0x000f --nodaq".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()
time.sleep(10)
process.join()

del IPC_queue, process, parser

parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o LED_check -v -w -s 0x0008 -p {polarity} -d 0x1800 -a 0x000f --nodaq".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()
time.sleep(10)
process.join()

parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o LED_check -v -w -s 0x000C -p {polarity} -d 0x1800 -a 0x000f --nodaq".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()
time.sleep(10)
process.join()

del IPC_queue, process, parser

# %% [markdown]
# #### Without clear_fifo

# %%
# os.system("rm -r ../ETROC-Data/2023-11-02_Array_Test_Results/CanBeRemoved_Board0_NoLinkCheck/")
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o CanBeRemoved_Board013_NoLinkCheck -v -w -s 0x0000 -p {polarity} -d 0xb800 -a 0x00bb --check_valid_data_start --clear_error".split())
IPC_queue = multiprocessing.Queue()
# process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board013_NoLinkCheck'))
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj L1A BCR')
while not IPC_queue.empty():
    pass
time.sleep(10)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %%
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o clear_fifo -v -w -s 0x0004 -p {polarity} -d 0x3800 -a 0x0033 --clear_fifo --clear_error".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, None))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj L1A BCR')
while not IPC_queue.empty():
    pass
time.sleep(10)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %% [markdown]
# # Run DAQ with Self-Trigger

# %% [markdown]
# ## Find the right delay (use the middle of the three success modes, where both Qinj edges are caught)

# %% [markdown]
# ### Board 0 Only

# %%
for inum in range(475, 490, 1):
    trigger_bit_delay = inum
    print(inum)
    parser = parser_arguments.create_parser()
    (options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 20 -o CanBeRemoved_Board0_LinkCheck_selfTrigger_delay{inum} -v -w -s 0x0000 -p {polarity} -d {int('000111'+format(inum, '010b'), base=2)} -a 0x0001 --suppress_fillers --start_DAQ_pulse --stop_DAQ_pulse --check_valid_data_start".split())
    IPC_queue = multiprocessing.Queue()
    process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board0_LinkCheck_selfTrigger_delay{inum}'))
    process.start()

    IPC_queue.put('memoFC Start Triggerbit QInj BCR')
    while not IPC_queue.empty():
        pass
    time.sleep(10)
    IPC_queue.put('stop DAQ')
    IPC_queue.put('memoFC Triggerbit')
    while not IPC_queue.empty():
        pass
    IPC_queue.put('allow threads to exit')
    process.join()

    del IPC_queue, process, parser

# %% [markdown]
# #### test delay from previous cell

# %%
trigger_bit_delay = int('000111'+format(484, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o CanBeRemoved_Board0_selfTrigger -v -w -s 0x0000 -p {polarity} -d {trigger_bit_delay} -a 0x0001 --clear_fifo --start_DAQ_pulse --stop_DAQ_pulse --check_valid_data_start --suppress_fillers".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board0_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
# IPC_queue.put('memoFC Start Triggerbit BCR')
while not IPC_queue.empty():
    pass
time.sleep(10)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %% [markdown]
# ### Board 1

# %%
for inum in range(475, 490, 1):
    trigger_bit_delay = inum
    print(inum)
    parser = parser_arguments.create_parser()
    (options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 20 -o CanBeRemoved_Board1_LinkCheck_selfTrigger_delay{inum} -v -w -s 0x0004 -p {polarity} -d {int('001011'+format(inum, '010b'), base=2)} -a 0x0022".split())
    IPC_queue = multiprocessing.Queue()
    process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board1_LinkCheck_selfTrigger_delay{inum}'))
    process.start()

    IPC_queue.put('memoFC Start Triggerbit QInj BCR')
    while not IPC_queue.empty():
        pass
    time.sleep(10)
    IPC_queue.put('stop DAQ')
    IPC_queue.put('memoFC Triggerbit')
    while not IPC_queue.empty():
        pass
    IPC_queue.put('allow threads to exit')
    process.join()

    del IPC_queue, process, parser

# %% [markdown]
# #### test delay from previous cell

# %%
trigger_bit_delay = int('001011'+format(484, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 65 -o CanBeRemoved_Board1_selfTrigger -v -w -s 0x0004 -p {polarity} -d {trigger_bit_delay} -a 0x000f --check_valid_data_start".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board2_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
while not IPC_queue.empty():
    pass
time.sleep(60)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %% [markdown]
# ### Board 2

# %%
for inum in range(475, 490, 1):
    trigger_bit_delay = inum
    print(inum)
    parser = parser_arguments.create_parser()
    (options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 20 -o CanBeRemoved_Board2_LinkCheck_selfTrigger_delay{inum} -v -w -s 0x0008 -p {polarity} -d {int('010011'+format(inum, '010b'), base=2)} -a 0x0044".split())
    IPC_queue = multiprocessing.Queue()
    process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board2_LinkCheck_selfTrigger_delay{inum}'))
    process.start()

    IPC_queue.put('memoFC Start Triggerbit QInj BCR')
    while not IPC_queue.empty():
        pass
    time.sleep(10)
    IPC_queue.put('stop DAQ')
    IPC_queue.put('memoFC Triggerbit')
    while not IPC_queue.empty():
        pass
    IPC_queue.put('allow threads to exit')
    process.join()

    del IPC_queue, process, parser

# %% [markdown]
# #### test delay from previous cell

# %%
trigger_bit_delay = int('010011'+format(484, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 25 -o CanBeRemoved_Board2_selfTrigger -v -w -s 0x0008 -p {polarity} -d {trigger_bit_delay} -a 0x000f --check_valid_data_start".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board2_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
while not IPC_queue.empty():
    pass
time.sleep(20)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %% [markdown]
# ### Board 3

# %%
for inum in range(475, 490, 1):
    trigger_bit_delay = inum
    print(inum)
    parser = parser_arguments.create_parser()
    (options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 20 -o CanBeRemoved_Board3_LinkCheck_selfTrigger_delay{inum} -v -w -s 0x000C -p {polarity} -d {int('100011'+format(inum, '010b'), base=2)} -a 0x0088".split())
    IPC_queue = multiprocessing.Queue()
    process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board3_LinkCheck_selfTrigger_delay{inum}'))
    process.start()

    IPC_queue.put('memoFC Start Triggerbit QInj BCR')
    while not IPC_queue.empty():
        pass
    time.sleep(10)
    IPC_queue.put('stop DAQ')
    IPC_queue.put('memoFC Triggerbit')
    while not IPC_queue.empty():
        pass
    IPC_queue.put('allow threads to exit')
    process.join()

    del IPC_queue, process, parser

# %% [markdown]
# #### test delay from previous cell

# %%
trigger_bit_delay = int('100011'+format(484, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o CanBeRemoved_Board3_selfTrigger -v -w -s 0x000C -p {polarity} -d {trigger_bit_delay} -a 0x000f --clear_fifo --check_valid_data_start".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board3_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
while not IPC_queue.empty():
    pass
time.sleep(10)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %% [markdown]
# ## Multiple Boards

# %%
trigger_bit_delay = int('101011'+format(485, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 30 -o CanBeRemoved_Board13_selfTrigger -v -w -s 0x0000 -p {polarity} -d {trigger_bit_delay} -a 0x00bb".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board0_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
while not IPC_queue.empty():
    pass
time.sleep(20)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %%
trigger_bit_delay = int('000111'+format(485, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 30 -o CanBeRemoved_Board0_selfTrigger_QInj_Readout013 -v -w -s 0x0000 -p {polarity} -d {trigger_bit_delay} -a 0x000b".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board0_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
while not IPC_queue.empty():
    pass
time.sleep(20)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %%
trigger_bit_delay = int('000111'+format(485, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 320 -o CanBeRemoved_Board0_selfTrigger_Readout013 -v -w -s 0x0000 -p {polarity} -d {trigger_bit_delay} -a 0x000b --check_valid_data_start --clear_fifo".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board0_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit BCR')
while not IPC_queue.empty():
    pass
time.sleep(300)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %%
trigger_bit_delay = int('100111'+format(484, '010b'), base=2)
parser = parser_arguments.create_parser()
(options, args) = parser.parse_args(args=f"-f --useIPC --hostname {hostname} -t 15 -o CanBeRemoved_Board03_selfTrigger -v -w -s 0x0000 -p {polarity} -d {trigger_bit_delay} -a 0x000f --clear_fifo --check_valid_data_start".split())
IPC_queue = multiprocessing.Queue()
process = multiprocessing.Process(target=run_script.main_process, args=(IPC_queue, options, f'main_process_Start_LEDs_Board0_selfTrigger'))
process.start()

IPC_queue.put('memoFC Start Triggerbit QInj BCR')
while not IPC_queue.empty():
    pass
time.sleep(10)
IPC_queue.put('stop DAQ')
IPC_queue.put('memoFC Triggerbit')
while not IPC_queue.empty():
    pass
IPC_queue.put('allow threads to exit')
process.join()

del IPC_queue, process, parser

# %% [markdown]
# # Disconnect I2C Device

# %%
del i2c_conn
